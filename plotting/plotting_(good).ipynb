# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# ## 1 Comparing the two ‘dialects’

# %% [markdown]
# ### 1.1 Some nomenclature

# %% [markdown]
# Using Object Oriented(OO) interface instead of pyplot(plt) interface for more nuanced control over our plots

# %% [markdown]
# ### 1.2 We need some data.

# %%
from matplotlib import pyplot as plt
import numpy

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %% [markdown]
# ### 1.3 Here comes the comparison

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %%
# plyplot interface
plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()
plt.show()

# %%
# OO interface
fig, ax = plt.subplots(nrows=1, ncols=1) # subplots, 1 row and 1 column. "fig" and "ax" are dummy variables
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()
plt.show()

# %% [markdown]
# ## 2 Using the OO Interface

# %% [markdown]
# ### 2.1 Getting ax

# %%
fig, ax = plt.subplots(ncols=1, nrows=2) # one column, two rows
# this gives you two axes so that you can plot in both planes

# %% [markdown]
# ### 2.2 What is ax

# %%
type(ax)
# "ax" is a numpy array
# Out:
# numpy.ndarray

# %%
ax.shape
# "ax" has two "things"
# Out:
# (2,)

# %%
type(ax[0])
# "ax contains a matplotlib axis"
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ### 2.3 Plots in a column

# %%
# first plot
fig, ax = plt.subplots(ncols=1, nrows=2)
ax[0].plot(x, cos_x, label='cos x')
# why can't I see any cos x label?

# %%
# second plot
fig, ax = plt.subplots(ncols=1, nrows=2)
ax[1].plot(x, sin_x, label='sin x')
# why can't I see any 'sin x' label?

# %% [markdown]
# ### 2.4 Legends

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)
ax[0].plot(x, cos_x, label='cos x')
ax[0].legend()

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)
ax[1].plot(x, sin_x, label='sin x')
ax[1].legend()

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
for a in ax:        # "a" here is a dummy variable, as usual
    a.legend()
# using a 'for' loop to show the legends for both axes without having two seperate cells

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
for a in ax:
    a.legend()
    a.grid(alpha=.25) # this adds a grid to the axes

# %% [markdown]
# ### 2.5 Tweaks

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 10),   # 10 x 5 inches!
                       sharex=True)      # this makes the two plots share the same x-axis
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
ax[1].set_xlabel('$x$')          #this adds an x label. note that you have to use set_xlabel for OO interface
ax[0].fill_between(x, 0, cos_x, alpha=.5)  # this 'colours' the spaces between the graph and the specified value
ax[1].fill_between(x, 0.5, sin_x, alpha=.25)

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')  # adds a supertitle to the figure
fig.tight_layout()

for a in ax:
    a.legend()
    a.grid(alpha=.25)

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 10),   # 10 x 5 inches!
                       sharex=True)      # this makes the two plots share the same x-axis
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
ax[1].set_xlabel('$x$')
for a in ax:
    a.legend()
    a.grid(alpha=.25)

# %%
# my full code
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 5),   # 5 x 5 inches!
                       sharex=True)  
ax[0].plot(x, cos_x, label='cos x')
ax[0].fill_between(x, 0, cos_x, alpha=.25) 
ax[1].plot(x, sin_x, label='sin x')
ax[1].fill_between(x, 0, sin_x, alpha=.25)


for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)
    
ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

plt.show()

# %%
# my full code with 'fig tight layout'
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 5),   # 5 x 5 inches!
                       sharex=True)  
ax[0].plot(x, cos_x, label='cos x')
ax[0].fill_between(x, 0, cos_x, alpha=.25) 
ax[1].plot(x, sin_x, label='sin x')
ax[1].fill_between(x, 0, sin_x, alpha=.25)


for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)
    
ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')

plt.show()

# %%
# full code
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(10, 5),   # 10 x 5 inches!
                       sharex=True)
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

plt.show()

# %% [markdown]
# ## 3 More rows and columns

# %% [markdown]
# ### 3.1 Using ax

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4),
                       sharex='col', sharey='col')  # why is it 'col' instead of 'true' now?

# Some variables to access the axes and improve readabilty
top_left, top_right, bottom_left, bottom_right = ax.flatten()

# x data for plotting
x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %%
ax.shape() # why can't I get the [2,2] output?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 ax.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# accessing each of the axes by using the appropriate 'coordinates'
ax[0, 0].plot(x1, np.ones_like(x1))
ax[0, 1].plot(x2, 2*np.ones_like(x2))
ax[1, 0].plot(x1, 3*np.ones_like(x1))
ax[1, 1].plot(x2, 4**np.ones_like(x2))
# am I supposed to plot anything using this cell?

# %%
# assigning your own variable names to each of the axes for convenience
top_left=ax[0, 0]
top_right=ax[0, 1]
bottom_left=ax[1, 0]
bottom_right=ax[1, 1]

# %%
top_left, top_right, bottom_left, bottom_right = ax.flatten()
# flattens a 2D array into 1D array. unpacking takes care of the assignments
# ^ I don't understand this. What does unpacking mean and how does it 'take care' of the assignments?

# %% [markdown]
# ### 3.2 Sharing axes

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, # without sharing axes, matplotlib will auto-scale both scales
                       figsize=(10, 4))

# Some variables to access the axes and improve readabilty
top_left, top_right, bottom_left, bottom_right = ax.flatten()

# x data for plotting
x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# True: makes all the axes use the same range
#
# col: use the same range for all the columns
#
# row: use the same range for all the rows

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4),
                       sharex=True, sharey='row') # all x-axes share same range, only the rows for y-axes share same range

# Some variables to access the axes and improve readabilty
top_left, top_right, bottom_left, bottom_right = ax.flatten()

# x data for plotting
x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# The most 'correct' option is the one that highlights the story that you are trying to convey with your plot

# %% [markdown]
# ### 3.3 Accessing all axes

# %%
# a way of applying changes to all the axes
top_left.grid(alpha=.25)
top_right.grid(alpha=.25)
bottom_left.grid(alpha=.25)
bottom_right.grid(alpha=.25)

# %%
# a more efficient way using a 'for' loop
for a in ax.flatten():
    a.grid(alpha=.25)

# %% [markdown]
# ## 4 Other useful plots

# %% [markdown]
# ### 4.1 Histograms

# %%
data = {}

filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv'
data['All'] = np.loadtxt(filename, skiprows=1)

filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv'
data['NUS'] = np.loadtxt(filename, skiprows=1)

plt.style.use('bmh')

plt.hist([data['All'], data['NUS']],
         bins=50,                        # How many bins to split the data into
         label=['All', 'NUS']
         )
plt.xlabel('Mean of Basic Montly Earning (S$)') # typo corrected
plt.ylabel('Number of Students')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.2 Scatter plots

# %%
data = {}
for label in ['All', 'NUS']:
    filename = f'sg-gov-graduate-employment-survey_basic_monthly_mean_{label.lower()}.csv'
    data[label] = np.loadtxt(filename, skiprows=1)

plt.style.use('seaborn-darkgrid')

for label, numbers in data.items():
    x = range(len(numbers)) # the range being the length of all the numbers(?)
    y = numbers
    plt.scatter(x, y, label=label, alpha=.5)

plt.xlabel('Position in the list')
plt.ylabel('Mean of Basic Montly Eraning (S$)')
plt.legend()
plt.show()

# what does this warning message mean?
# Out:
# C:\Users\Khai Tjie\AppData\Local\Temp\ipykernel_14848\3001551369.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ### 4.3 Bar charts

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('ggplot')
plt.bar(majors, numbers)
plt.xlabel('Majors')
plt.ylabel('Number of Students')

plt.show()

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('ggplot')
plt.barh(majors, numbers)  # 'barh()' for horizontal bars 
plt.xlabel('Majors')
plt.ylabel('Number of Students')

plt.show()

# %% [markdown]
# ### 4.4 Pie charts

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('fivethirtyeight')
plt.pie(numbers, 
        labels=majors,
        autopct='%1.1f%%',   # How to format the percentages
        startangle=-90                
        )
plt.title('Percentage of each major')
plt.show()

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('fivethirtyeight')
plt.pie(numbers, 
        labels=majors,
        autopct='%1.1f%%',   # What does 'format the percentages' mean?
        startangle= 0                # where is the start point?
        )
plt.title('Percentage of each major')
plt.show()

# %% [markdown]
# ## Exercise 1 :  Plotting data from files

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1, color='g', alpha=.125)
axes[0, 0].set_xlabel('Angle (radians)')
axes[0, 0].text(0, 0, 'I am [0, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, cos_x, -2, color='r', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('Cosine Value')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='lower right', frameon=False)
axes[0, 1].text(0, 0, 'I am [0, 1]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
axes[1, 0].fill_between(x, fun1_x, 0, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend()
axes[1, 0].text(0, 0, 'I am [1, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, 10, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].legend()
axes[1, 1].text(0, 0, 'I am [1, 1]!', fontsize=30,
                horizontalalignment='center')

# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

# plt.tight_layout()
plt.show()

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1, color='r', alpha=.125)
axes[0, 0].set_xlabel('Angle (radians)')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -2, color='g', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('Cosine Value')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='lower right', frameon=False)

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
axes[1, 0].fill_between(x, np.exp(-x) * np.cos(5 * x), color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend()


#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, 10, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].legend()


# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

# plt.tight_layout()
plt.show()
